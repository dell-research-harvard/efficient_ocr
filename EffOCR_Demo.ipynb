# %%
### Install EffOCR Package
# pip install effocr

# %%
### Import
from efficient_ocr import EffOCR
import cv2

# %% [markdown]
# ## 0. Config

# %%
### Show Config, editing, etc.

# %% [markdown]
# ## 1. Zero Shot Inference

# %%
from IPython.display import Image, display

# %%
### Demonstrate Zero Shot capabilities

### Read Images (find friendly examples)
img_fp =r'C:\Users\bryan\Documents\NBER\efficient_ocr\tests\fixtures\test_locca_image.jpg'

### Display within notebook
display(Image(img_fp))

# %%
config_file = r'.\config\config_en_full.yaml'
engine = EffOCR(data_json, image_dir, config_file)
# Out:
# YOLOv5  2023-8-3 Python-3.8.13 torch-1.10.1+cpu CPU
#
# Fusing layers...
# Model summary: 214 layers, 7022326 parameters, 0 gradients, 15.9 GFLOPs
# Adding AutoShape...
# YOLOv5  2023-8-3 Python-3.8.13 torch-1.10.1+cpu CPU
#
# Fusing layers...
# Model summary: 214 layers, 7025023 parameters, 0 gradients, 16.0 GFLOPs
# Adding AutoShape...

# %%
# Run EffOCR
result = engine.infer(img_fp, visualize=r'.\data')

# Display results
print(result[0].text)
# Out:
# The tug boat Alice. with Captain
# Rollie Davis and Harry Raymond on
# board. returned to juneau carly this
# morning. The Alice left here last
# week for Thomas Bay to pick up q
# tow Of piles for the Treadwell com
# pany. The tow, which consists OF
# about 400 piles. rs tied up at Taku
# Harbor as the high winds prevented
# towing.
#
# I'VE bucked bucked the wind down
# and we bucked the wind back. part
# of the time making less than n hall
# mile on hour" said Harry Raymond
# this morning.
#
# AS soon as the weather moderates
# the Alice win leave and bring In the
# Tow and will then return to Thomas
# Bay and pick up q tow of piles for
# delivery In juneau.

# %%
# Show Visualization

display(Image('./data/0.png'))

# %% [markdown]
# ## 2. Few Shot Learning

# %%
### Show

# %% [markdown]
# ## 3. End-to-End Training

# %%
### Show data json, image folder, demonstrate full training
